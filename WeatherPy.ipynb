# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 580

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
units = "metric"
url = f"http://api.openweathermap.org/data/2.5/weather?units={units}&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lihue
# Processing Record 2 of Set 1 | chibougamau
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | bereeda
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | moyale
# Processing Record 7 of Set 1 | fale old settlement
# Processing Record 8 of Set 1 | olonkinbyen
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | remire-montjoly
# Processing Record 11 of Set 1 | george town
# Processing Record 12 of Set 1 | talara
# Processing Record 13 of Set 1 | ad dilam
# Processing Record 14 of Set 1 | puerto eldorado
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | barranca
# Processing Record 17 of Set 1 | la ronge
# Processing Record 18 of Set 1 | badger
# Processing Record 19 of Set 1 | newman
# Processing Record 20 of Set 1 | castillos
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | bilibino
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | nova sintra
# Processing Record 25 of Set 1 | enewetak
# Processing Record 26 of Set 1 | klyuchi
# Processing Record 27 of Set 1 | edinburgh of the seven seas
# Processing Record 28 of Set 1 | adamstown
# Processing Record 29 of Set 1 | papatowai
# Processing Record 30 of Set 1 | coahuayana de hidalgo
# Processing Record 31 of Set 1 | leava
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | bikenibeu village
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | talnakh
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | constantia
# Processing Record 40 of Set 1 | yulinshi
# Processing Record 41 of Set 1 | puerto natales
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | el granada
# Processing Record 44 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 45 of Set 1 | pangody
# Processing Record 46 of Set 1 | ust-nera
# Processing Record 47 of Set 1 | susuman
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | kunashak
# Processing Record 50 of Set 1 | turuntayevo
# Processing Record 0 of Set 2 | kingston
# Processing Record 1 of Set 2 | grytviken
# Processing Record 2 of Set 2 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 3 of Set 2 | hanceville
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | sil-li
# Processing Record 7 of Set 2 | vytegra
# Processing Record 8 of Set 2 | coquimbo
# Processing Record 9 of Set 2 | nuuk
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | cable beach
# City not found. Skipping...
# Processing Record 13 of Set 2 | blackmans bay
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | mejit
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | beswan
# Processing Record 20 of Set 2 | port mathurin
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | yenangyaung
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | st. john's
# Processing Record 26 of Set 2 | paragominas
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | morristown
# Processing Record 29 of Set 2 | suntar
# Processing Record 30 of Set 2 | illapel
# Processing Record 31 of Set 2 | usogorsk
# Processing Record 32 of Set 2 | kununurra
# Processing Record 33 of Set 2 | grand gaube
# Processing Record 34 of Set 2 | happy valley-goose bay
# Processing Record 35 of Set 2 | isafjordur
# Processing Record 36 of Set 2 | den burg
# Processing Record 37 of Set 2 | ancud
# Processing Record 38 of Set 2 | invercargill
# Processing Record 39 of Set 2 | port-vila
# Processing Record 40 of Set 2 | guerrero negro
# Processing Record 41 of Set 2 | gadzhiyevo
# Processing Record 42 of Set 2 | saint stephens
# Processing Record 43 of Set 2 | dahme
# Processing Record 44 of Set 2 | callao
# Processing Record 45 of Set 2 | zouerate
# Processing Record 46 of Set 2 | ebaye
# Processing Record 47 of Set 2 | namdrik
# Processing Record 48 of Set 2 | bloemfontein
# Processing Record 49 of Set 2 | necochea
# Processing Record 0 of Set 3 | wailua homesteads
# Processing Record 1 of Set 3 | stanley
# Processing Record 2 of Set 3 | utrik
# Processing Record 3 of Set 3 | omarska
# Processing Record 4 of Set 3 | west island
# Processing Record 5 of Set 3 | beau vallon
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | daru
# Processing Record 8 of Set 3 | rabo de peixe
# Processing Record 9 of Set 3 | ndungu
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | norilsk
# Processing Record 12 of Set 3 | govindgarh
# Processing Record 13 of Set 3 | qaqortoq
# Processing Record 14 of Set 3 | kataba
# Processing Record 15 of Set 3 | taungdwingyi
# Processing Record 16 of Set 3 | chernyshevskiy
# Processing Record 17 of Set 3 | fort st. john
# Processing Record 18 of Set 3 | asau village
# City not found. Skipping...
# Processing Record 19 of Set 3 | bhum
# Processing Record 20 of Set 3 | beitbridge
# Processing Record 21 of Set 3 | atafu village
# Processing Record 22 of Set 3 | minas de marcona
# Processing Record 23 of Set 3 | senador jose porfirio
# Processing Record 24 of Set 3 | conceicao da barra
# Processing Record 25 of Set 3 | umarga
# Processing Record 26 of Set 3 | kulob
# Processing Record 27 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 3 | puduppatti
# Processing Record 29 of Set 3 | anadyr
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | hell-ville
# Processing Record 32 of Set 3 | ambatolampy
# Processing Record 33 of Set 3 | hamilton
# Processing Record 34 of Set 3 | oye-plage
# Processing Record 35 of Set 3 | cole harbour
# Processing Record 36 of Set 3 | punta arenas
# Processing Record 37 of Set 3 | udachny
# Processing Record 38 of Set 3 | tafo
# Processing Record 39 of Set 3 | puerto madryn
# Processing Record 40 of Set 3 | acarau
# Processing Record 41 of Set 3 | mumford
# Processing Record 42 of Set 3 | keflavik
# Processing Record 43 of Set 3 | freetown
# Processing Record 44 of Set 3 | kiknur
# Processing Record 45 of Set 3 | sinabang
# Processing Record 46 of Set 3 | nantucket
# Processing Record 47 of Set 3 | haiku-pauwela
# Processing Record 48 of Set 3 | qandala
# Processing Record 49 of Set 3 | biloela
# Processing Record 0 of Set 4 | cabo san lucas
# Processing Record 1 of Set 4 | troitsko-pechorsk
# Processing Record 2 of Set 4 | vadso
# Processing Record 3 of Set 4 | nar'yan-mar
# Processing Record 4 of Set 4 | katsuren-haebaru
# Processing Record 5 of Set 4 | cronulla
# Processing Record 6 of Set 4 | gelibolu
# Processing Record 7 of Set 4 | puerto lempira
# Processing Record 8 of Set 4 | tolanaro
# Processing Record 9 of Set 4 | tabou
# Processing Record 10 of Set 4 | victoria point
# Processing Record 11 of Set 4 | lobujya
# Processing Record 12 of Set 4 | wisconsin rapids
# Processing Record 13 of Set 4 | horta
# Processing Record 14 of Set 4 | kalachinsk
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | kamloops
# Processing Record 17 of Set 4 | mazara del vallo
# Processing Record 18 of Set 4 | taltal
# Processing Record 19 of Set 4 | igarka
# Processing Record 20 of Set 4 | lompoc
# Processing Record 21 of Set 4 | kasongo-lunda
# Processing Record 22 of Set 4 | menongue
# Processing Record 23 of Set 4 | tazovsky
# Processing Record 24 of Set 4 | yaring
# Processing Record 25 of Set 4 | tsimasham
# Processing Record 26 of Set 4 | howard springs
# Processing Record 27 of Set 4 | dingli
# Processing Record 28 of Set 4 | sao vicente
# Processing Record 29 of Set 4 | vyazemskiy
# Processing Record 30 of Set 4 | hirara
# Processing Record 31 of Set 4 | tromso
# Processing Record 32 of Set 4 | hammerfest
# Processing Record 33 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 34 of Set 4 | kitimat
# Processing Record 35 of Set 4 | vorgashor
# Processing Record 36 of Set 4 | angaur state
# Processing Record 37 of Set 4 | santiago de cao
# Processing Record 38 of Set 4 | sassandra
# Processing Record 39 of Set 4 | whakatane
# Processing Record 40 of Set 4 | nchelenge
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | soe
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | isle of lewis
# City not found. Skipping...
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | bandarbeyla
# Processing Record 47 of Set 4 | dabakala
# Processing Record 48 of Set 4 | buta
# Processing Record 49 of Set 4 | le port
# Processing Record 0 of Set 5 | hawaiian paradise park
# Processing Record 1 of Set 5 | kismayo
# Processing Record 2 of Set 5 | aasiaat
# Processing Record 3 of Set 5 | sola
# Processing Record 4 of Set 5 | saldanha
# Processing Record 5 of Set 5 | saladas
# Processing Record 6 of Set 5 | yanykurgan
# Processing Record 7 of Set 5 | madang
# Processing Record 8 of Set 5 | nadi
# Processing Record 9 of Set 5 | jianshui
# Processing Record 10 of Set 5 | puerto santa
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | orange
# Processing Record 13 of Set 5 | iskateley
# Processing Record 14 of Set 5 | sydney
# Processing Record 15 of Set 5 | derzhavinsk
# Processing Record 16 of Set 5 | djibo
# Processing Record 17 of Set 5 | malaga
# Processing Record 18 of Set 5 | yamada
# Processing Record 19 of Set 5 | gornyatskiy
# Processing Record 20 of Set 5 | tura
# Processing Record 21 of Set 5 | severo-yeniseyskiy
# Processing Record 22 of Set 5 | mil'kovo
# Processing Record 23 of Set 5 | colonia
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | cherven bryag
# Processing Record 26 of Set 5 | port lincoln
# Processing Record 27 of Set 5 | brigantine
# Processing Record 28 of Set 5 | masterton
# Processing Record 29 of Set 5 | funtua
# Processing Record 30 of Set 5 | bandon
# Processing Record 31 of Set 5 | puerto baquerizo moreno
# Processing Record 32 of Set 5 | frontera
# Processing Record 33 of Set 5 | 'amran
# City not found. Skipping...
# Processing Record 34 of Set 5 | raja
# Processing Record 35 of Set 5 | ola
# Processing Record 36 of Set 5 | pont-l'abbe
# City not found. Skipping...
# Processing Record 37 of Set 5 | queenstown
# Processing Record 38 of Set 5 | mahina
# Processing Record 39 of Set 5 | zag
# Processing Record 40 of Set 5 | bela vista
# Processing Record 41 of Set 5 | san antonio de pale
# Processing Record 42 of Set 5 | newberry
# Processing Record 43 of Set 5 | thayetmyo
# Processing Record 44 of Set 5 | broken hill
# Processing Record 45 of Set 5 | christchurch
# Processing Record 46 of Set 5 | vorkuta
# Processing Record 47 of Set 5 | xilin hot
# Processing Record 48 of Set 5 | zeribet el oued
# Processing Record 49 of Set 5 | amarillo
# Processing Record 0 of Set 6 | marsh harbour
# Processing Record 1 of Set 6 | tofol
# Processing Record 2 of Set 6 | zeya
# Processing Record 3 of Set 6 | uturoa
# Processing Record 4 of Set 6 | vernon
# Processing Record 5 of Set 6 | dalandzadgad
# Processing Record 6 of Set 6 | bykovo
# Processing Record 7 of Set 6 | afaahiti
# Processing Record 8 of Set 6 | sittwe
# Processing Record 9 of Set 6 | touros
# Processing Record 10 of Set 6 | cabedelo
# Processing Record 11 of Set 6 | bazar-e yakawlang
# City not found. Skipping...
# Processing Record 12 of Set 6 | aitape
# Processing Record 13 of Set 6 | chegdomyn
# Processing Record 14 of Set 6 | tarnow
# Processing Record 15 of Set 6 | aldan
# Processing Record 16 of Set 6 | bharatpur
# Processing Record 17 of Set 6 | limbe
# Processing Record 18 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 6 | malango
# Processing Record 20 of Set 6 | bredy
# Processing Record 21 of Set 6 | jayapura
# Processing Record 22 of Set 6 | perugorria
# Processing Record 23 of Set 6 | stornoway
# Processing Record 24 of Set 6 | kapuskasing
# Processing Record 25 of Set 6 | yuzhno-kurilsk
# Processing Record 26 of Set 6 | topolobampo
# Processing Record 27 of Set 6 | strelka
# Processing Record 28 of Set 6 | dudinka
# Processing Record 29 of Set 6 | ambanja
# Processing Record 30 of Set 6 | alaghsas
# Processing Record 31 of Set 6 | college
# Processing Record 32 of Set 6 | chonchi
# Processing Record 33 of Set 6 | san ignacio
# Processing Record 34 of Set 6 | santana
# Processing Record 35 of Set 6 | kruisfontein
# Processing Record 36 of Set 6 | sundargarh
# Processing Record 37 of Set 6 | kailua-kona
# Processing Record 38 of Set 6 | crane
# Processing Record 39 of Set 6 | craig
# Processing Record 40 of Set 6 | mili
# Processing Record 41 of Set 6 | valdosta
# Processing Record 42 of Set 6 | ad dabbah
# Processing Record 43 of Set 6 | qui nhon
# Processing Record 44 of Set 6 | mount isa
# Processing Record 45 of Set 6 | bijie
# Processing Record 46 of Set 6 | extrema
# Processing Record 47 of Set 6 | fort stockton
# Processing Record 48 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 49 of Set 6 | puerto cabezas
# Processing Record 0 of Set 7 | tocopilla
# Processing Record 1 of Set 7 | yurty
# Processing Record 2 of Set 7 | bowen
# Processing Record 3 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 7 | codrington
# Processing Record 5 of Set 7 | san luis de la loma
# Processing Record 6 of Set 7 | floro
# Processing Record 7 of Set 7 | new plymouth
# Processing Record 8 of Set 7 | natal
# Processing Record 9 of Set 7 | sudzha
# Processing Record 10 of Set 7 | tomatlan
# Processing Record 11 of Set 7 | kura
# Processing Record 12 of Set 7 | manta
# Processing Record 13 of Set 7 | huaicheng
# Processing Record 14 of Set 7 | tinajo
# Processing Record 15 of Set 7 | barra
# Processing Record 16 of Set 7 | bukama
# Processing Record 17 of Set 7 | durban
# Processing Record 18 of Set 7 | katsuura
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | selfoss
# Processing Record 21 of Set 7 | marsabit
# Processing Record 22 of Set 7 | colinas
# Processing Record 23 of Set 7 | lacin
# Processing Record 24 of Set 7 | puerto del rosario
# Processing Record 25 of Set 7 | morelos
# Processing Record 26 of Set 7 | new norfolk
# Processing Record 27 of Set 7 | antsiranana
# Processing Record 28 of Set 7 | auki
# Processing Record 29 of Set 7 | urangan
# Processing Record 30 of Set 7 | quatre cocos
# Processing Record 31 of Set 7 | nagqu
# Processing Record 32 of Set 7 | marivan
# Processing Record 33 of Set 7 | arraial do cabo
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | mount pearl
# Processing Record 37 of Set 7 | leo
# Processing Record 38 of Set 7 | yutz
# Processing Record 39 of Set 7 | tobol'sk
# Processing Record 40 of Set 7 | hadibu
# Processing Record 41 of Set 7 | kirakira
# Processing Record 42 of Set 7 | khandyga
# Processing Record 43 of Set 7 | nguigmi
# Processing Record 44 of Set 7 | road town
# Processing Record 45 of Set 7 | muravlenko
# Processing Record 46 of Set 7 | nyurba
# Processing Record 47 of Set 7 | fengxian
# Processing Record 48 of Set 7 | lembar
# City not found. Skipping...
# Processing Record 49 of Set 7 | tobruk
# Processing Record 0 of Set 8 | gaoual
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | nemuro
# Processing Record 3 of Set 8 | rychnov nad kneznou
# Processing Record 4 of Set 8 | taikang
# Processing Record 5 of Set 8 | puerto aysen
# Processing Record 6 of Set 8 | rosario del tala
# Processing Record 7 of Set 8 | praia da vitoria
# Processing Record 8 of Set 8 | cidade velha
# Processing Record 9 of Set 8 | nova vicosa
# Processing Record 10 of Set 8 | kargasok
# Processing Record 11 of Set 8 | usakos
# Processing Record 12 of Set 8 | kilindoni
# Processing Record 13 of Set 8 | ulladulla
# Processing Record 14 of Set 8 | upper grand lagoon
# Processing Record 15 of Set 8 | mondragon
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | peniche
# Processing Record 18 of Set 8 | envira
# Processing Record 19 of Set 8 | kenai
# Processing Record 20 of Set 8 | alofi
# Processing Record 21 of Set 8 | baihar
# Processing Record 22 of Set 8 | ba
# City not found. Skipping...
# Processing Record 23 of Set 8 | polyarnyy
# Processing Record 24 of Set 8 | bel ombre
# Processing Record 25 of Set 8 | al-`ula
# City not found. Skipping...
# Processing Record 26 of Set 8 | carutapera
# Processing Record 27 of Set 8 | westport
# Processing Record 28 of Set 8 | ta`u
# Processing Record 29 of Set 8 | cannonvale
# Processing Record 30 of Set 8 | rongelap
# Processing Record 31 of Set 8 | howrah
# Processing Record 32 of Set 8 | mwinilunga
# Processing Record 33 of Set 8 | rio grande
# Processing Record 34 of Set 8 | suva
# Processing Record 35 of Set 8 | urucara
# Processing Record 36 of Set 8 | port saint john's
# Processing Record 37 of Set 8 | lagos
# Processing Record 38 of Set 8 | clodomira
# Processing Record 39 of Set 8 | kavaratti
# Processing Record 40 of Set 8 | urzhar
# Processing Record 41 of Set 8 | athlone
# Processing Record 42 of Set 8 | rajula
# Processing Record 43 of Set 8 | forio
# Processing Record 44 of Set 8 | itigi
# Processing Record 45 of Set 8 | aloja
# Processing Record 46 of Set 8 | tafuna
# Processing Record 47 of Set 8 | chibuto
# Processing Record 48 of Set 8 | sao joao da barra
# Processing Record 49 of Set 8 | kakching
# Processing Record 0 of Set 9 | isangel
# Processing Record 1 of Set 9 | dawei
# Processing Record 2 of Set 9 | mbeni
# Processing Record 3 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 9 | tokar
# Processing Record 5 of Set 9 | timimoun
# Processing Record 6 of Set 9 | revelstoke
# Processing Record 7 of Set 9 | garissa
# Processing Record 8 of Set 9 | lucapa
# Processing Record 9 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 10 of Set 9 | valenca do piaui
# Processing Record 11 of Set 9 | altay
# Processing Record 12 of Set 9 | bubaque
# Processing Record 13 of Set 9 | sao desiderio
# Processing Record 14 of Set 9 | hobyo
# Processing Record 15 of Set 9 | luau
# Processing Record 16 of Set 9 | mizdah
# Processing Record 17 of Set 9 | kovalam
# Processing Record 18 of Set 9 | saipan
# Processing Record 19 of Set 9 | ust'-kut
# Processing Record 20 of Set 9 | yuli
# Processing Record 21 of Set 9 | saint-joseph
# Processing Record 22 of Set 9 | hassi messaoud
# Processing Record 23 of Set 9 | kuta
# Processing Record 24 of Set 9 | santaluz
# Processing Record 25 of Set 9 | labytnangi
# Processing Record 26 of Set 9 | petoskey
# Processing Record 27 of Set 9 | sao mateus
# Processing Record 28 of Set 9 | sawakin
# Processing Record 29 of Set 9 | holualoa
# Processing Record 30 of Set 9 | guajara mirim
# Processing Record 31 of Set 9 | oistins
# Processing Record 32 of Set 9 | kataysk
# Processing Record 33 of Set 9 | east ballina
# Processing Record 34 of Set 9 | nishinoomote
# Processing Record 35 of Set 9 | dwarka
# Processing Record 36 of Set 9 | basco
# Processing Record 37 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 9 | akureyri
# Processing Record 39 of Set 9 | murghob
# Processing Record 40 of Set 9 | voinjama
# Processing Record 41 of Set 9 | ushibukamachi
# Processing Record 42 of Set 9 | hepo
# Processing Record 43 of Set 9 | weno
# Processing Record 44 of Set 9 | veshenskaya
# Processing Record 45 of Set 9 | powell river
# Processing Record 46 of Set 9 | iraucuba
# Processing Record 47 of Set 9 | salekhard
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | trenggalek
# Processing Record 0 of Set 10 | opuwo
# Processing Record 1 of Set 10 | lospalos
# Processing Record 2 of Set 10 | concordia
# Processing Record 3 of Set 10 | kudahuvadhoo
# Processing Record 4 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | ngama
# Processing Record 6 of Set 10 | pontalina
# Processing Record 7 of Set 10 | souillac
# Processing Record 8 of Set 10 | fukui-shi
# Processing Record 9 of Set 10 | gypsum
# Processing Record 10 of Set 10 | babayevo
# Processing Record 11 of Set 10 | calama
# Processing Record 12 of Set 10 | magadan
# Processing Record 13 of Set 10 | ponta delgada
# Processing Record 14 of Set 10 | rawah
# Processing Record 15 of Set 10 | karratha
# Processing Record 16 of Set 10 | santa elena de uairen
# Processing Record 17 of Set 10 | nakamura
# Processing Record 18 of Set 10 | galveston
# Processing Record 19 of Set 10 | vilyuysk
# Processing Record 20 of Set 10 | mabaruma
# Processing Record 21 of Set 10 | san mateo del mar
# Processing Record 22 of Set 10 | murun-kuren
# Processing Record 23 of Set 10 | myeik
# Processing Record 24 of Set 10 | mahajanga
# Processing Record 25 of Set 10 | tralee
# Processing Record 26 of Set 10 | bluefields
# Processing Record 27 of Set 10 | bani walid
# Processing Record 28 of Set 10 | kisi
# Processing Record 29 of Set 10 | sincik
# Processing Record 30 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 10 | el paraiso
# Processing Record 32 of Set 10 | borba
# Processing Record 33 of Set 10 | port macquarie
# Processing Record 34 of Set 10 | santo antonio do ica
# Processing Record 35 of Set 10 | ad douiem
# Processing Record 36 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 37 of Set 10 | vilyuchinsk
# Processing Record 38 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 39 of Set 10 | olinda
# Processing Record 40 of Set 10 | oranjemund
# Processing Record 41 of Set 10 | prince rupert
# Processing Record 42 of Set 10 | xining
# Processing Record 43 of Set 10 | saint-francois
# Processing Record 44 of Set 10 | nikolayevsk-on-amure
# Processing Record 45 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 46 of Set 10 | francistown
# Processing Record 47 of Set 10 | carbonear
# Processing Record 48 of Set 10 | yaren
# Processing Record 49 of Set 10 | visby
# Processing Record 0 of Set 11 | klaksvik
# Processing Record 1 of Set 11 | tindouf
# Processing Record 2 of Set 11 | islamkot
# Processing Record 3 of Set 11 | chongoyape
# Processing Record 4 of Set 11 | cacapava do sul
# Processing Record 5 of Set 11 | ust'-kulom
# Processing Record 6 of Set 11 | lichuan
# Processing Record 7 of Set 11 | ojinaga
# Processing Record 8 of Set 11 | suoyarvi
# Processing Record 9 of Set 11 | zaragoza
# Processing Record 10 of Set 11 | kerikeri
# Processing Record 11 of Set 11 | kayenta
# Processing Record 12 of Set 11 | la'ie
# Processing Record 13 of Set 11 | long mountain
# Processing Record 14 of Set 11 | brush
# Processing Record 15 of Set 11 | markovo
# Processing Record 16 of Set 11 | shahrak-e pabedana
# City not found. Skipping...
# Processing Record 17 of Set 11 | centenario do sul
# Processing Record 18 of Set 11 | hohhot
# Processing Record 19 of Set 11 | lianzhou
# Processing Record 20 of Set 11 | qadirpur ran
# Processing Record 21 of Set 11 | altai
# Processing Record 22 of Set 11 | miracema do tocantins
# Processing Record 23 of Set 11 | anna regina
# Processing Record 24 of Set 11 | kandi
# Processing Record 25 of Set 11 | greenville
# Processing Record 26 of Set 11 | revda
# Processing Record 27 of Set 11 | kota tinggi
# Processing Record 28 of Set 11 | panghyon-dong
# Processing Record 29 of Set 11 | peterhead
# Processing Record 30 of Set 11 | jiwani
# Processing Record 31 of Set 11 | pariaman
# Processing Record 32 of Set 11 | flin flon
# Processing Record 33 of Set 11 | manokwari
# Processing Record 34 of Set 11 | kincardine
# Processing Record 35 of Set 11 | nurota
# Processing Record 36 of Set 11 | letlhakeng
# Processing Record 37 of Set 11 | zapata
# Processing Record 38 of Set 11 | gobabis
# Processing Record 39 of Set 11 | isetskoye
# Processing Record 40 of Set 11 | bochum
# Processing Record 41 of Set 11 | novodvinsk
# Processing Record 42 of Set 11 | berdigestyakh
# Processing Record 43 of Set 11 | juan griego
# Processing Record 44 of Set 11 | bonthe
# Processing Record 45 of Set 11 | pumiao
# Processing Record 46 of Set 11 | liupanshui
# City not found. Skipping...
# Processing Record 47 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 11 | roma
# Processing Record 49 of Set 11 | fort mcmurray
# Processing Record 0 of Set 12 | taoyuan city
# Processing Record 1 of Set 12 | verkhovazh'ye
# Processing Record 2 of Set 12 | tartouss
# Processing Record 3 of Set 12 | bathsheba
# Processing Record 4 of Set 12 | al qubbah
# Processing Record 5 of Set 12 | qamdo
# Processing Record 6 of Set 12 | ed damer
# Processing Record 7 of Set 12 | bakau
# Processing Record 8 of Set 12 | el matama
# Processing Record 9 of Set 12 | peru
# Processing Record 10 of Set 12 | ambatofinandrahana
# Processing Record 11 of Set 12 | majene
# Processing Record 12 of Set 12 | acajutla
# Processing Record 13 of Set 12 | borgosesia
# Processing Record 14 of Set 12 | port moresby
# Processing Record 15 of Set 12 | mlalo
# Processing Record 16 of Set 12 | valparaiso
# Processing Record 17 of Set 12 | waitara
# Processing Record 18 of Set 12 | illizi
# Processing Record 19 of Set 12 | belokurikha
# Processing Record 20 of Set 12 | san mariano
# Processing Record 21 of Set 12 | timmins
# Processing Record 22 of Set 12 | jisr ash shughur
# Processing Record 23 of Set 12 | atar
# Processing Record 24 of Set 12 | quellon
# Processing Record 25 of Set 12 | benton
# Processing Record 26 of Set 12 | rurrenabaque
# Processing Record 27 of Set 12 | berezovyy
# Processing Record 28 of Set 12 | pimentel
# Processing Record 29 of Set 12 | arteche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              lihue  21.9789 -159.3672     29.58        74          40
# 1        chibougamau  49.9168  -74.3659     18.79        52           0
# 2  port-aux-francais -49.3500   70.2167      1.00        71          10
# 3            bereeda  11.8704   51.0579     27.09        71          15
# 4        port alfred -33.5906   26.8910     16.77        83          89
#
#    Wind Speed Country        Date
# 0        5.14      US  1696027976
# 1        3.09      CA  1696028003
# 2       18.77      TF  1696027956
# 3        1.59      SO  1696028514
# 4        3.10      ZA  1696027970

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                    lihue  21.9789 -159.3672     29.58        74          40
# 1              chibougamau  49.9168  -74.3659     18.79        52           0
# 2        port-aux-francais -49.3500   70.2167      1.00        71          10
# 3                  bereeda  11.8704   51.0579     27.09        71          15
# 4              port alfred -33.5906   26.8910     16.77        83          89
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1696027976
# 1              3.09      CA  1696028003
# 2             18.77      TF  1696027956
# 3              1.59      SO  1696028514
# 4              3.10      ZA  1696027970

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitudes = city_data_df["Lat"]
temperature = city_data_df["Max Temp"]
plt.figure(figsize=(6.3,5))
plt.scatter(latitudes,temperature,edgecolor="black") 

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature "+ time.strftime("(%Y-%m-%d)"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.xlim(min(latitudes)-7,max(latitudes)+7)
plt.ylim(min(temperature)-20,max(temperature)+20)
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitudes = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
plt.figure(figsize=(6.3,5))
plt.scatter(latitudes,humidity,edgecolor="black") 

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("(%Y-%m-%d)"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.xlim(min(latitudes)-7,max(latitudes)+7)
plt.ylim(min(humidity)-10,max(humidity)+10)
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
latitudes = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
plt.figure(figsize=(6.3,5))
plt.scatter(latitudes,cloudiness,edgecolor="black") 

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("(%Y-%m-%d)"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.xlim(min(latitudes)-7,max(latitudes)+7)
plt.ylim(min(cloudiness)-10,max(cloudiness)+10)
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitudes = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
plt.figure(figsize=(6.3,5))
plt.scatter(latitudes,cloudiness,edgecolor="black") 

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("(%Y-%m-%d)"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.xlim(min(latitudes)-7,max(latitudes)+7)
plt.ylim(min(cloudiness)-10,max(cloudiness)+10)
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitudes = city_data_df["Lat"]
wind_speed = city_data_df["Wind Speed"]
plt.figure(figsize=(6.3,5))
plt.scatter(latitudes,wind_speed,edgecolor="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind speed "+ time.strftime("(%Y-%m-%d)"))
plt.ylabel("Wind speed (m/s)")
plt.xlabel("Latitude")
plt.xlim(min(latitudes)-7,max(latitudes)+7)
plt.ylim(min(wind_speed)-0.75,max(wind_speed)+1)
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def linear_regression_plot(x_values, y_values, x_label, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    print(f"The r-value is: {rvalue}")
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.figure(figsize=(6.3,5))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values,"r-")
    plt.annotate(line_eq, xy=(min(x_values),min(y_values)), fontsize=15, color="red")
    plt.title(f"City {x_label} vs. {y_label} "+ time.strftime("(%Y-%m-%d)"))
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              lihue  21.9789 -159.3672     29.58        74          40
# 1        chibougamau  49.9168  -74.3659     18.79        52           0
# 3            bereeda  11.8704   51.0579     27.09        71          15
# 5             moyale   3.5167   39.0584     19.84        86          20
# 7        olonkinbyen  70.9221   -8.7187      2.44        83         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1696027976
# 1              3.09      CA  1696028003
# 3              1.59      SO  1696028514
# 5              3.68      KE  1696028514
# 7              6.62      SJ  1696027959

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0] 

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2          port-aux-francais -49.3500   70.2167      1.00        71
# 4                port alfred -33.5906   26.8910     16.77        83
# 6        fale old settlement  -9.3852 -171.2468     28.72        71
# 11                    talara  -4.5772  -81.2719     24.42        69
# 13           puerto eldorado -26.4084  -54.6946     20.03        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                10       18.77      TF  1696027956
# 4                89        3.10      ZA  1696027970
# 6                42        5.53      TK  1696027980
# 11                0        5.53      PE  1696028245
# 13               72        0.29      AR  1696028515

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"],
                       "Latitude","Max Temp")
# Out:
# The r-value is: -0.8191417816603644

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],
                         "Latitude","Max Temp")
# Out:
# The r-value is: 0.7993480745283276

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Northern Hemisphere:**
# Maximum temperature and latitude are strongly inversely correlated, according to the negative r-value of about -0.819. The maximum temperature tends to drop as latitude rises (going northward from the equator). Temperatures tend to drop as one begins to approach the North Pole and travel farther from the equator.
#
# **Southern Hemisphere:**
# A serious positive relationship between latitude and maximum temperature is shown by the positive r-value, which is roughly 0.799. The maximum temperature tends to rise as you descend in latitude (go closer to the equator).Temperatures increase near the equator and decrease as you approach the South Pole.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Humidity"],
                       "Latitude","Humidity")
# Out:
# The r-value is: 0.08470945962598514

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Humidity"],
                         "Latitude","Humidity")
# Out:
# The r-value is: 0.013408848589289426

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Northern Hemisphere:**
# Latitude and humidity in the Northern Hemisphere have been shown to have a very weakly positive relationship, according to the positive r-value of around 0.085. There is only a very minor trend for humidity to rise as one ascend higher latitudes and move farther from the equator.Latitude alone is not a reliable indicator of humidity, according to this poor association.
#
# **Southern Hemisphere:**
# Latitude and humidity appear to have only a very weakly positive relationship, according to the positive r-value of around 0.013.Similar to the Northern Hemisphere, also shows a very minor tendency for humidity to rise as one approach the equator and does not appear to have a substantial correlation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"],
                       "Latitude","Cloudiness")
# Out:
# The r-value is: 0.17622394014825443

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"],
                         "Latitude","Cloudiness")
# Out:
# The r-value is: 0.09684590501676578

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Northern Hemisphere:**
# An approximate positive relationship between latitude and cloudiness is indicated by the positive r-value of 0.176. There is a low trend for cloudiness to rise as one ascend higher latitudes and move farther from the equator. Latitude alone does not strongly predict cloudiness, as seen by the correlation's continued weak.
#
# **Southern Hemisphere:**
# Latitude and cloudiness appear to be weakly positively correlated, according to the positive r-value of about 0.097. Closer to the equator, there is a modest trend for cloudiness to rise. This association is weak, similar to that in the Northern Hemisphere, indicating that latitude is not the main factor affecting cloudiness levels.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"],
                       "Latitude","Wind Speed")
# Out:
# The r-value is: -0.027861871267536864

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"],
                         "Latitude","Wind Speed")
# Out:
# The r-value is: -0.15092363486655433

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Northern Hemisphere:**
# Latitude and wind speed seem to have a very weak negative association, according to the negative r-value of about -0.028. As one go northward and away from the equator, there is a very little tendency for wind speed to decrease. The correlation is incredibly weak, indicating that latitude is not a reliable predictor of wind speed on itself.
#
# **Southern Hemisphere:**
# A slight negative relationship between latitude and wind speed is indicated by the negative r-value, which is around -0.151. As one moves closer to the equator, there is a little stronger trend for the wind speed to drop. The fact that this correlation is still slightly important, similar to in the Northern Hemisphere, shows that latitude is not a very reliable predictor of wind speed.
