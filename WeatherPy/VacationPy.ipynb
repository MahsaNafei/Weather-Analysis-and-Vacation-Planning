# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0              lihue  21.9789 -159.3672     29.58        74
# 1        1        chibougamau  49.9168  -74.3659     18.79        52
# 2        2  port-aux-francais -49.3500   70.2167      1.00        71
# 3        3            bereeda  11.8704   51.0579     27.09        71
# 4        4        port alfred -33.5906   26.8910     16.77        83
#
#    Cloudiness  Wind Speed Country        Date
# 0          40        5.14      US  1696027976
# 1           0        3.09      CA  1696028003
# 2          10       18.77      TF  1696027956
# 3          15        1.59      SO  1696028514
# 4          89        3.10      ZA  1696027970

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      size = "Humidity",
                                      tiles = "OSM",
                                      frame_width = 700,
                                      frame_height = 500,
                                      scale = 1,
                                      color = "City",
                                      alpha = 0.5
                                     )
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_city = city_data_df[(city_data_df["Max Temp"] < 35) &
                             (city_data_df["Max Temp"] > 22) &
                             (city_data_df["Wind Speed"] < 10) &
                             (city_data_df["Cloudiness"] < 15) &
                             (city_data_df["Humidity"] > 60) &
                             (city_data_df["Humidity"] < 80)]

# Drop any rows with null values
ideal_city = ideal_city.dropna()
ideal_city
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 9          9     remire-montjoly   4.9167  -52.2667     28.02        78
# 11        11              talara  -4.5772  -81.2719     24.42        69
# 65        65           hithadhoo  -0.6000   73.0833     27.93        77
# 75        75          morristown  36.2140  -83.2949     25.39        64
# 80        80         grand gaube -20.0064   57.6608     23.22        76
# 87        87      guerrero negro  27.9769 -114.0611     22.28        64
# 128      128            hamilton  39.1834  -84.5333     25.00        71
# 155      155      victoria point -27.5833  153.3000     23.97        73
# 205      205              orange  33.7000 -117.7675     26.54        70
# 233      233            newberry  34.2746  -81.6187     26.68        71
# 311      311  puerto del rosario  28.5004  -13.8627     23.86        73
# 335      335              tobruk  32.0836   23.9764     23.71        75
# 350      350  upper grand lagoon  30.1633  -85.7408     28.08        71
# 377      377               forio  40.7342   13.8646     22.51        68
# 381      381             chibuto -24.6867   33.5306     22.58        72
# 387      387               tokar  18.4254   37.7290     29.26        74
# 406      406            santaluz -11.2558  -39.3747     24.12        63
# 410      410             sawakin  19.1059   37.3321     30.00        75
# 415      415        east ballina -28.8667  153.5833     23.78        66
# 416      416        nishinoomote  30.7333  131.0000     26.11        75
# 422      422       ushibukamachi  32.1906  130.0228     25.38        70
# 448      448           galveston  29.3669  -94.9669     32.32        67
# 462      462      port macquarie -31.4333  152.9167     22.72        61
# 525      525            tartouss  34.8890   35.8866     26.12        68
#
#      Cloudiness  Wind Speed Country        Date
# 9             0        2.57      GF  1696028038
# 11            0        5.53      PE  1696028245
# 65            4        6.77      MV  1696028020
# 75            0        1.54      US  1696028462
# 80            2        0.45      MU  1696028521
# 87            1        7.25      MX  1696027967
# 128           0        0.89      US  1696027914
# 155           3        1.34      AU  1696028529
# 205          13        1.34      US  1696028399
# 233           4        1.99      US  1696028539
# 311           0        0.51      ES  1696028558
# 335           0        3.61      LY  1696028561
# 350           0        2.06      US  1696028562
# 377           0        1.51      IT  1696028565
# 381           0        3.67      MZ  1696028566
# 387           0        1.61      SD  1696028566
# 406           4        7.23      BR  1696028568
# 410           1        2.43      SD  1696028569
# 415           9        3.50      AU  1696028569
# 416          11        3.95      JP  1696027989
# 422           0        1.01      JP  1696028570
# 448           0        0.45      US  1696028342
# 462           0        3.35      AU  1696028052
# 525           4        7.21      SY  1696028579

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city[["City","Country","Lat","Lng","Humidity"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 9       remire-montjoly      GF   4.9167  -52.2667        78
# 11               talara      PE  -4.5772  -81.2719        69
# 65            hithadhoo      MV  -0.6000   73.0833        77
# 75           morristown      US  36.2140  -83.2949        64
# 80          grand gaube      MU -20.0064   57.6608        76
# 87       guerrero negro      MX  27.9769 -114.0611        64
# 128            hamilton      US  39.1834  -84.5333        71
# 155      victoria point      AU -27.5833  153.3000        73
# 205              orange      US  33.7000 -117.7675        70
# 233            newberry      US  34.2746  -81.6187        71
# 311  puerto del rosario      ES  28.5004  -13.8627        73
# 335              tobruk      LY  32.0836   23.9764        75
# 350  upper grand lagoon      US  30.1633  -85.7408        71
# 377               forio      IT  40.7342   13.8646        68
# 381             chibuto      MZ -24.6867   33.5306        72
# 387               tokar      SD  18.4254   37.7290        74
# 406            santaluz      BR -11.2558  -39.3747        63
# 410             sawakin      SD  19.1059   37.3321        75
# 415        east ballina      AU -28.8667  153.5833        66
# 416        nishinoomote      JP  30.7333  131.0000        75
# 422       ushibukamachi      JP  32.1906  130.0228        70
# 448           galveston      US  29.3669  -94.9669        67
# 462      port macquarie      AU -31.4333  152.9167        61
# 525            tartouss      SY  34.8890   35.8866        68

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000

params = {"categories":"accommodation.hotel",
          "limit": 20,
          "apiKey": geoapify_key
          }


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url,params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")


hotel_df
# Out:
# Starting hotel search
# remire-montjoly - nearest hotel: Complexe Belova
# talara - nearest hotel: Hospedaje El Aypate
# hithadhoo - nearest hotel: Pebbles Inn
# morristown - nearest hotel: Days Inn
# grand gaube - nearest hotel: Hotel Lux- Grand Gaube
# guerrero negro - nearest hotel: Plaza sal paraiso
# hamilton - nearest hotel: North Vista Manor
# victoria point - nearest hotel: Seminara Appartments
# orange - nearest hotel: La Quinta Inn & Suites
# newberry - nearest hotel: Hampton Inn Newberry-Opera House
# puerto del rosario - nearest hotel: Hotel Tamasite
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
# upper grand lagoon - nearest hotel: Hampton Inn Panama City Beach
# forio - nearest hotel: Hotel Terme Colella
# chibuto - nearest hotel: DESHENG
# tokar - nearest hotel: No hotel found
# santaluz - nearest hotel: No hotel found
# sawakin - nearest hotel: Hotel Halfa
# east ballina - nearest hotel: Ballina Beach Resort
# nishinoomote - nearest hotel: ゼウスハウス
# ushibukamachi - nearest hotel: Hotel Harbor Inn
# galveston - nearest hotel: Comfort Inn & Suites Texas City
# port macquarie - nearest hotel: The Observatory
# tartouss - nearest hotel: فندق انترادوس
#                    City Country      Lat       Lng  Humidity  \
# 9       remire-montjoly      GF   4.9167  -52.2667        78
# 11               talara      PE  -4.5772  -81.2719        69
# 65            hithadhoo      MV  -0.6000   73.0833        77
# 75           morristown      US  36.2140  -83.2949        64
# 80          grand gaube      MU -20.0064   57.6608        76
# 87       guerrero negro      MX  27.9769 -114.0611        64
# 128            hamilton      US  39.1834  -84.5333        71
# 155      victoria point      AU -27.5833  153.3000        73
# 205              orange      US  33.7000 -117.7675        70
# 233            newberry      US  34.2746  -81.6187        71
# 311  puerto del rosario      ES  28.5004  -13.8627        73
# 335              tobruk      LY  32.0836   23.9764        75
# 350  upper grand lagoon      US  30.1633  -85.7408        71
# 377               forio      IT  40.7342   13.8646        68
# 381             chibuto      MZ -24.6867   33.5306        72
# 387               tokar      SD  18.4254   37.7290        74
# 406            santaluz      BR -11.2558  -39.3747        63
# 410             sawakin      SD  19.1059   37.3321        75
# 415        east ballina      AU -28.8667  153.5833        66
# 416        nishinoomote      JP  30.7333  131.0000        75
# 422       ushibukamachi      JP  32.1906  130.0228        70
# 448           galveston      US  29.3669  -94.9669        67
# 462      port macquarie      AU -31.4333  152.9167        61
# 525            tartouss      SY  34.8890   35.8866        68
#
#                            Hotel Name
# 9                     Complexe Belova
# 11                Hospedaje El Aypate
# 65                        Pebbles Inn
# 75                           Days Inn
# 80             Hotel Lux- Grand Gaube
# 87                  Plaza sal paraiso
# 128                 North Vista Manor
# 155              Seminara Appartments
# 205            La Quinta Inn & Suites
# 233  Hampton Inn Newberry-Opera House
# 311                    Hotel Tamasite
# 335           فندق زهرة البطنان -طبرق
# 350     Hampton Inn Panama City Beach
# 377               Hotel Terme Colella
# 381                           DESHENG
# 387                    No hotel found
# 406                    No hotel found
# 410                       Hotel Halfa
# 415              Ballina Beach Resort
# 416                            ゼウスハウス
# 422                  Hotel Harbor Inn
# 448   Comfort Inn & Suites Texas City
# 462                   The Observatory
# 525                     فندق انترادوس

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
city_hotel_map = hotel_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      size = "Humidity",
                                      tiles = "OSM",
                                      frame_width = 700,
                                      frame_height = 500,
                                      scale = 1,
                                      color = "City",
                                      alpha = 0.5,
                                      hover_cols=["Hotel Name","City", "Country"]
                                     )

city_hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
